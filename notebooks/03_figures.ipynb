# %% [markdown]
# # 03 — Figures
#
# This notebook displays all 6 publication figures generated by the simulation pipeline.
# No figures are regenerated here; they are loaded from `outputs/figures/`.

# %%
from IPython.display import display, Image
from pathlib import Path
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

# %% [markdown]
# ## Figure 1: Pareto Frontier and Policy Sweet-Spot

# %%
display(Image(filename='outputs/figures/fig1_frontier.png', width=700))

# %% [markdown]
# ## Figure 2: Grid Search Heatmap
#
# Detection rate and throughput across safety × evidence gate threshold combinations.

# %%
display(Image(filename='outputs/figures/fig2_heatmap.png', width=700))

# %% [markdown]
# ## Figure 3: Sobol Sensitivity Ranking
#
# Total-order indices for 7 parameters across 4 outcome metrics.

# %%
display(Image(filename='outputs/figures/fig3_sensitivity.png', width=700))

# %% [markdown]
# ## Figure 4: Lifecycle Drift Dynamics
#
# Performance decay, cumulative harm, and re-audit triggers over 12 time periods.

# %%
display(Image(filename='outputs/figures/fig4_drift.png', width=700))

# %% [markdown]
# ## Figure 5: Decision Curve Analysis
#
# Net benefit of governance policies across harm–benefit preference thresholds.

# %%
display(Image(filename='outputs/figures/fig5_dca.png', width=700))

# %% [markdown]
# ## Figure 6: Structural Causal Model DAG
#
# 28 nodes, 19 edges encoding causal relationships among latent traits, intermediates, and outcomes.

# %%
display(Image(filename='outputs/figures/fig6_scm.png', width=700))
